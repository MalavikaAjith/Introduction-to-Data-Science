# %% [markdown]
# <a href="https://colab.research.google.com/github/MalavikaAjith/Introduction-to-Data-Science/blob/main/12_Matplotlib_Concepts_Lecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'r')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Title String')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')
plt.subplot(1,2,2)
plt.plot(y,x,'g*-')

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])
axes.plot(x,y,'b')
axes.set_xlabel('X Axis')
axes.set_ylabel('Y Axis')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])
axes1.plot(x,y,'b')
axes1.set_xlabel('X Axis')
axes1.set_ylabel('Y Axis')
axes1.set_title('Title')
axes2.plot(y,x,'g')
axes2.set_xlabel('X Axis')
axes2.set_ylabel('Y Axis')
axes2.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig, axes = plt.subplots()
axes.plot(x,y,'b')
axes.set_xlabel('X Axis')
axes.set_ylabel('Y Axis')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
fig,axes= plt.subplots(nrows=1,ncols=2)
for ax in axes:
  ax.plot(x,y,'g')
  ax.set_xlabel('X Axis')
  ax.set_ylabel('Y Axis')
  ax.set_title('Title')
  fig
  plt.tight_layout()

# %%
fig,axes=plt.subplots(figsize=(12,3), dpi=50)
axes.plot(x,y,'b')
axes.set_xlabel('X Axis')
axes.set_ylabel('Y Axis')
axes.set_title('Title')
# Out:
# Text(0.5, 1.0, 'Title')

# %%
fig.savefig("filename.png")

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label='x**2')
ax.plot(x,x**3,label='x**3')
ax.legend()
